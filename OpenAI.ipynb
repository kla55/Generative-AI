# %%
import pandas as pd 
import openai
# Out:
# C:\Users\Kenneth\AppData\Local\Temp\ipykernel_19180\214903877.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
my_key = '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'

# %%
openai.api_key = my_key

# %%
list(openai.models.list())
# Out:
# [Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'),
#  Model(id='text-embedding-3-large', created=1705953180, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-0613', created=1686587434, object='model', owned_by='openai'),
#  Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-instruct-0914', created=1694122472, object='model', owned_by='system'),
#  Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'),
#  Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'),
#  Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'),
#  Model(id='babbage-002', created=1692634615, object='model', owned_by='system'),
#  Model(id='text-embedding-3-small', created=1705948997, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-instruct', created=1692901427, object='model', owned_by='system'),
# ...

# %%
pd.DataFrame(list(openai.models.list()))
# Out:
#                                     0                      1                2  \
# 0                      (id, dall-e-3)  (created, 1698785189)  (object, model)
# 1        (id, text-embedding-3-large)  (created, 1705953180)  (object, model)
# 2            (id, gpt-3.5-turbo-0613)  (created, 1686587434)  (object, model)
# 3                      (id, dall-e-2)  (created, 1698798177)  (object, model)
# 4   (id, gpt-3.5-turbo-instruct-0914)  (created, 1694122472)  (object, model)
# 5                     (id, whisper-1)  (created, 1677532384)  (object, model)
# 6                 (id, tts-1-hd-1106)  (created, 1699053533)  (object, model)
# 7                      (id, tts-1-hd)  (created, 1699046015)  (object, model)
# 8                   (id, babbage-002)  (created, 1692634615)  (object, model)
# 9        (id, text-embedding-3-small)  (created, 1705948997)  (object, model)
# 10       (id, gpt-3.5-turbo-instruct)  (created, 1692901427)  (object, model)
# ...

# %%
from openai import OpenAI
client = OpenAI(api_key=my_key,)

response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": "how to I sleep on time"
    }
  ],
  temperature=1,
  max_tokens=10,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[20], line 4
#       1 from openai import OpenAI
#       2 client = OpenAI(api_key=my_key,)
# ----> 4 response = client.chat.completions.create(
#       5   model="gpt-3.5-turbo",
#       6   messages=[
#       7     {
#       8       "role": "user",
#       9       "content": "how to I sleep on time"
#      10     }
#      11   ],
#      12   temperature=1,
#      13   max_tokens=10,
#      14   top_p=1,
#      15   frequency_penalty=0,
#      16   presence_penalty=0
#      17 )
#
# File ~\anaconda3\envs\cuda_venv\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# ...

# %%
type(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 type(response)
#
# NameError: name 'response' is not defined
